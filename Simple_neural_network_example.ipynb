# %% [markdown]
# <a href="https://colab.research.google.com/github/dpanagop/ML_and_AI_examples/blob/master/Simple_neural_network_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple neural network example

# %% [markdown]
# ###First, we load the necessary libraries

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ###Then, we create a simple neural network

# %%
model=keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.add(keras.layers.Dense(1))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0716 11:11:20.355340 140689434380160 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ###Next, compile the model

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ###Create
# 1. input data, variable x
# 2. target data, variable y
#
# Note that: $y=2x-1$

# %%
x=np.array([-1, 0,1,2,3,4],dtype=float)
y=np.array([-3,-1,1,3,5,7],dtype=float)

# %% [markdown]
# ###Train model

# %%
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 1s 83ms/sample - loss: 26.0347
# Epoch 2/500
# 6/6 [==============================] - 0s 774us/sample - loss: 19.9218
# Epoch 3/500
# 6/6 [==============================] - 0s 615us/sample - loss: 16.5734
# Epoch 4/500
# 6/6 [==============================] - 0s 581us/sample - loss: 14.2282
# Epoch 5/500
# 6/6 [==============================] - 0s 558us/sample - loss: 12.2851
# Epoch 6/500
# 6/6 [==============================] - 0s 503us/sample - loss: 10.4984
# Epoch 7/500
# 6/6 [==============================] - 0s 600us/sample - loss: 8.7823
# Epoch 8/500
# 6/6 [==============================] - 0s 632us/sample - loss: 7.1440
# Epoch 9/500
# 6/6 [==============================] - 0s 207us/sample - loss: 5.6455
# Epoch 10/500
# 6/6 [==============================] - 0s 209us/sample - loss: 4.3646
# Epoch 11/500
# 6/6 [==============================] - 0s 210us/sample - loss: 3.3553
# Epoch 12/500
# ...

# %% [markdown]
# ###Use model to predict responce with $x=3.5$ as input.
# ###Based on formula $y=2x-1$ the predicted value should be close to 6.

# %%
print(model.predict([3.5]))
# Out:
# [[5.9999995]]

# %% [markdown]
# ###We can view a summary of the model

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 4
# Trainable params: 4
# Non-trainable params: 0
# _________________________________________________________________
